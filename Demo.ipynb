# %%
from data_resources import fileToObjects
from map_based_resources import transformObjects, mapResources, singleTile

# %%
configuration = mapResources.MapResources()
standardized_rendering_pixel_size = configuration.standardized_rendering_pixel_size

coordinates = transformObjects.get_datapoints_from_json(fileToObjects.open_json_file('coordinates.json'))

# %%
list_of_images_and_points = singleTile.get_image_and_plot(coordinates[0], configuration)

# %%
cropped = singleTile.get_image_and_plot(coordinates[0], configuration,show=False).get_cropped_images(2)
for cropped_image in cropped:
    display(cropped_image)
# Out:
# <PIL.Image.Image image mode=RGB size=16x16 at 0x119FBDD10>
# <PIL.Image.Image image mode=RGB size=16x16 at 0x11AB22750>
# <PIL.Image.Image image mode=P size=16x16 at 0x119DE1DD0>
# <PIL.Image.Image image mode=RGBA size=16x16 at 0x119DE1790>
# <PIL.Image.Image image mode=RGBA size=8x8 at 0x119DE1650>
# <PIL.Image.Image image mode=LA size=8x8 at 0x119DE1110>
# <PIL.Image.Image image mode=RGBA size=16x16 at 0x119DE1890>

# %%
cropped_images = cropped.copy()
previous_image_size = None
for cropped_image in cropped_images:
    index = cropped_images.index(cropped_image)
    print(index,cropped_image.mode)
    if cropped_image.mode in ['LA','P']:
        cropped_image = cropped_image.convert('RGBA')
    cropped_image = cropped_image.convert('HSV')
    if previous_image_size is not None and previous_image_size != cropped_image.size:
        cropped_image = cropped_image.resize(previous_image_size)
    previous_image_size = cropped_image.size
    cropped_images[index] = cropped_image 
    print(cropped_image.size)
    display(cropped_image.convert('RGBA'))
# Out:
# 0 RGB
# (16, 16)
# <PIL.Image.Image image mode=RGBA size=16x16 at 0x11AC43B90>
# 1 RGB
# (16, 16)
# <PIL.Image.Image image mode=RGBA size=16x16 at 0x11AC43410>
# 2 P
# (16, 16)
# <PIL.Image.Image image mode=RGBA size=16x16 at 0x11AC43F50>
# 3 RGBA
# (16, 16)
# <PIL.Image.Image image mode=RGBA size=16x16 at 0x11AC43150>
# 4 RGBA
# (16, 16)
# <PIL.Image.Image image mode=RGBA size=16x16 at 0x11AC43B90>
# 5 LA
# (16, 16)
# <PIL.Image.Image image mode=RGBA size=16x16 at 0x11AC43A50>
# 6 RGBA
# (16, 16)
# <PIL.Image.Image image mode=RGBA size=16x16 at 0x11AC43B90>
