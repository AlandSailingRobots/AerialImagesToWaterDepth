# %%
from data_resources import singleTile, fileToObjects
configuration = fileToObjects.get_configuration()
standardized_rendering_pixel_size = configuration.standardized_rendering_pixel_size

# %%
list_of_images_and_points = singleTile.get_image_and_plot(fileToObjects.get_coordinates_from_file()[1], configuration)

# %%
cropped_images = singleTile.get_image_and_plot(fileToObjects.get_coordinates_from_file()[1], configuration,show=False).get_cropped_images(3)
for cropped_image in cropped_images:
    display(cropped_image)
# Out:
# <PIL.Image.Image image mode=RGB size=24x24 at 0x115608780>
# <PIL.Image.Image image mode=RGB size=24x24 at 0x11561A208>
# <PIL.Image.Image image mode=P size=24x24 at 0x11561A198>
# <PIL.Image.Image image mode=RGBA size=24x24 at 0x11561A390>
# <PIL.Image.Image image mode=RGBA size=12x12 at 0x11561A9E8>
# <PIL.Image.Image image mode=LA size=12x12 at 0x11561A780>
# <PIL.Image.Image image mode=RGBA size=24x24 at 0x11561AD30>
